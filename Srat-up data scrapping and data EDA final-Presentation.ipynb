# %% [markdown]
# ## All hypothesis are tested on Number of active companies as main KPI for performance

# %% [markdown]
# ## 1. Hypotheis 1
#
#
# **We want to test which industry segment for  women-founded company has a higher count of active companies. Our initial assumption is that health care sector has more active companies than in b2b.**
#
# **Data is collected for all regions, all batches, all tags, and all states. Selection is applied for industry - women-founded companies in healthcare vs B2B Software services**
#
# **Our initial assumption was correct**

# %% [markdown]
# ## 2. Hypotheis 2
#
#
# **On the same KPI we want to test b2b across America / Canada vs Remote. The initial assumption is that America has more active vs Remote**
#
# **Data is collected for all batches and all states. Selection is applied for the industry - b2b, in regions America/Canada and Remote**
#
# **Our assumption was wrong**

# %% [markdown]
# ## 3. Hypotheis 3
#
#
# **On the same KPI we want to test b2b America vs b2b remote. Our initial assumption is that America should have more active companies in the sector**
#
# **Data is collected for all batches,  and all statates. Selection is applied for industry - SaaS  in regions America/Canada and Remote**
#
# **Our assumption was wrong**

# %% [markdown]
# ## 2. Hypotheis 4
#
#
# **On the same KPI we want to test b2b AI vs b2b developer tools. Our initial assumption is that ai should have more active companies in the sector.**
#
# **Data is collected for all batches, all tags and all statates. Selection is applied for industry - b2b  ,and tags ai and dev tools**
#
# **Our hypothesis was wrong**
